# %%
# import libraries
import geopandas as gpd
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import contextily as ctx

# %%
gdf = gpd.read_file('https://droughtmonitor.unl.edu/data/json/usdm_20230103.json')

# %%
gdf.head()
# Out:
#    OBJECTID  DM  Shape_Length  Shape_Area  \
# 0         1   0    807.484338  191.164520
# 1         2   1    668.966134  165.567295
# 2         3   2    460.458814  134.590821
# 3         4   3    220.940834   65.615568
# 4         5   4     49.303633   14.871497
#
#                                             geometry
# 0  MULTIPOLYGON (((-67.17698 18.00918, -67.17708 ...
# 1  MULTIPOLYGON (((-97.54037 26.82364, -97.54169 ...
# 2  MULTIPOLYGON (((-99.82151 28.29862, -99.83012 ...
# 3  MULTIPOLYGON (((-98.04065 30.43548, -98.10516 ...
# 4  MULTIPOLYGON (((-98.99397 29.43432, -98.80716 ...

# %%
countydf=pd.read_csv('RiversideImperialDrought.csv')

# %%
countydf.head()
# Out:
#     MapDate  FIPS           County State  None     D0     D1   D2   D3   D4  \
# 0  20230207  6025  Imperial County    CA   0.0  47.65  52.35  0.0  0.0  0.0
# 1  20230131  6025  Imperial County    CA   0.0  47.65  52.35  0.0  0.0  0.0
# 2  20230124  6025  Imperial County    CA   0.0  47.65  52.35  0.0  0.0  0.0
# 3  20230117  6025  Imperial County    CA   0.0  47.65  52.35  0.0  0.0  0.0
# 4  20230110  6025  Imperial County    CA   0.0  47.65  52.35  0.0  0.0  0.0
#
#    ValidStart    ValidEnd  StatisticFormatID
# 0  2023-02-07  2023-02-13                  2
# 1  2023-01-31  2023-02-06                  2
# 2  2023-01-24  2023-01-30                  2
# 3  2023-01-17  2023-01-23                  2
# 4  2023-01-10  2023-01-16                  2

# %%
newdf=gdf.sjoin(countydf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 newdf=gdf.sjoin(countydf)
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:2061, in GeoDataFrame.sjoin(self, df, *args, **kwargs)
#    1983 def sjoin(self, df, *args, **kwargs):
#    1984     """Spatial join of two GeoDataFrames.
#    1985
#    1986     See the User Guide page :doc:`../../user_guide/mergingdata` for details.
#    (...)
#    2059     sjoin : equivalent top-level function
#    2060     """
# -> 2061     return geopandas.sjoin(left_df=self, right_df=df, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/tools/sjoin.py:122, in sjoin(left_df, right_df, how, predicate, lsuffix, rsuffix, **kwargs)
#     119     first = next(iter(kwargs.keys()))
#     120     raise TypeError(f"sjoin() got an unexpected keyword argument '{first}'")
# ...
